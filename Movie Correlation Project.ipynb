# %%
# Import libraries

import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib
import matplotlib.pyplot as plt
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8)  #Adjusts configurations of the plots we would create

pd.options.mode.chained_assignment = None



# Now we need to read in the data
df = pd.read_csv(r'C:\Users\USER\Desktop\movies.csv')

# %%
#view the data

df.head()
# Out:
#    name  rating  genre  year  released  score      votes  director  writer  \
# 0  6587       6      6  1980      1705    8.4   927000.0      2589    4014
# 1  5573       6      1  1980      1492    5.8    65000.0      2269    1632
# 2  5142       4      0  1980      1771    8.7  1200000.0      1111    2567
# 3   286       4      4  1980      1492    7.7   221000.0      1301    2000
# 4  1027       6      4  1980      1543    7.3   108000.0      1054     521
#
#    star  country      budget        gross  company  runtime  year_correct
# 0  1047       54  19000000.0   46998772.0     2319    146.0          1124
# 1   327       55   4500000.0   58853106.0      731    104.0           922
# 2  1745       55  18000000.0  538375067.0     1540    124.0          1182
# 3  2246       55   3500000.0   83453539.0     1812     88.0           922
# 4   410       55   6000000.0   39846344.0     1777     98.0           971

# %%
# We need to see if we have any missing data
# Let's loop through the data and see if there is anything missing

for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{} - {}%'.format(col, round(pct_missing*100)))
# Out:
# name - 0%
# rating - 1%
# genre - 0%
# year - 0%
# released - 0%
# score - 0%
# votes - 0%
# director - 0%
# writer - 0%
# star - 0%
# country - 0%
# budget - 28%
# gross - 2%
# company - 0%
# runtime - 0%

# %%
# Data Types for our columns

print(df.dtypes)
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %%
df.sort_values (by = ['gross'], inplace=False, ascending=False)
# Out:
#       name  rating  genre  year  released  score      votes  director  writer  \
# 5445   533       5      0  2009       696    7.8  1100000.0      1155    1778
# 7445   535       5      0  2019       183    8.4   903000.0       162     743
# 3045  6896       5      6  1997       704    7.8  1100000.0      1155    1778
# 6663  5144       5      0  2015       698    7.8   876000.0      1125    2550
# 7244   536       5      0  2018       192    8.4   897000.0       162     743
#
#       star  country       budget         gross  company  runtime  year_correct
# 5445  2334       55  237000000.0  2.847246e+09     2253    162.0           548
# 7445  2241       55  356000000.0  2.797501e+09     1606    181.0           155
# 3045  1595       55  200000000.0  2.201647e+09     2253    194.0           549
# 6663   524       55  245000000.0  2.069522e+09     1540    138.0           548
# 7244  2241       55  321000000.0  2.048360e+09     1606    149.0           163

# %%
pd.set_option('display.max_rows', None)

# %%
#Drop any duplicates

df['company'].drop_duplicates().sort_values(ascending=False).head()
# Out:
# 7129    2384
# 5664    2383
# 6412    2382
# 4007    2381
# 6793    2380
# Name: company, dtype: int16

# %%
#Scatter plot with budget vs gross revenue

plt.scatter(x = df['budget'], y = df['gross'])

plt.title('Budget vs Gross Earnings')

plt.xlabel('Gross Earnings')

plt.ylabel('Budget for film')




plt.show()

# %%
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# 0             Stephen King  Jack Nicholson  United Kingdom  19000000.0
# 1  Henry De Vere Stacpoole  Brooke Shields   United States   4500000.0
# 2           Leigh Brackett     Mark Hamill   United States  18000000.0
# 3             Jim Abrahams     Robert Hays   United States   3500000.0
# 4       Brian Doyle-Murray     Chevy Chase   United States   6000000.0
#
#          gross             company  runtime     year_correct
# 0   46998772.0        Warner Bros.    146.0  June 13, 1980 (
# 1   58853106.0   Columbia Pictures    104.0  July 2, 1980 (U
# 2  538375067.0           Lucasfilm    124.0  June 20, 1980 (
# 3   83453539.0  Paramount Pictures     88.0  July 2, 1980 (U
# 4   39846344.0      Orion Pictures     98.0  July 25, 1980 (

# %%
#plot the budget vs gross using seaborn


sns.regplot(x = 'budget', y = 'gross', data = df, scatter_kws={"color":"black"}, line_kws={"color":"purple"})
# Out:
# <AxesSubplot:xlabel='budget', ylabel='gross'>

# %%
#looking at the corelation

# %%
df.corr()
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.097995  0.222945  0.329321  0.257486  0.120811
# score    0.097995  1.000000  0.409182  0.076254  0.186258  0.399451
# votes    0.222945  0.409182  1.000000  0.442429  0.630757  0.309212
# budget   0.329321  0.076254  0.442429  1.000000  0.740395  0.320447
# gross    0.257486  0.186258  0.630757  0.740395  1.000000  0.245216
# runtime  0.120811  0.399451  0.309212  0.320447  0.245216  1.000000

# %%
#high correlation between budget and gross

# %%
correlation_matrix = df.corr(method = 'pearson')

sns.heatmap(correlation_matrix, annot = True)

plt.title('Correlation Matrix for Numeric Features')

plt.xlabel('Movie features')

plt.ylabel('Movie features')

plt.show()

# %%
#look at company

# %%
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# 0             Stephen King  Jack Nicholson  United Kingdom  19000000.0
# 1  Henry De Vere Stacpoole  Brooke Shields   United States   4500000.0
# 2           Leigh Brackett     Mark Hamill   United States  18000000.0
# 3             Jim Abrahams     Robert Hays   United States   3500000.0
# 4       Brian Doyle-Murray     Chevy Chase   United States   6000000.0
#
#          gross             company  runtime     year_correct
# 0   46998772.0        Warner Bros.    146.0  June 13, 1980 (
# 1   58853106.0   Columbia Pictures    104.0  July 2, 1980 (U
# 2  538375067.0           Lucasfilm    124.0  June 20, 1980 (
# 3   83453539.0  Paramount Pictures     88.0  July 2, 1980 (U
# 4   39846344.0      Orion Pictures     98.0  July 25, 1980 (

# %%
df_numerized = df

for col_name in df_numerized.columns:
    if(df_numerized[col_name].dtype == 'object'):
        df_numerized[col_name] = df_numerized[col_name].astype('category')
        df_numerized[col_name] = df_numerized[col_name].cat.codes
        
df_numerized.head()
# Out:
#       name  rating  genre  year  released  score      votes  director  writer  \
# 5445   533       5      0  2009       696    7.8  1100000.0      1155    1778
# 7445   535       5      0  2019       183    8.4   903000.0       162     743
# 3045  6896       5      6  1997       704    7.8  1100000.0      1155    1778
# 6663  5144       5      0  2015       698    7.8   876000.0      1125    2550
# 7244   536       5      0  2018       192    8.4   897000.0       162     743
#
#       star  country       budget         gross  company  runtime  year_correct
# 5445  2334       55  237000000.0  2.847246e+09     2253    162.0           548
# 7445  2241       55  356000000.0  2.797501e+09     1606    181.0           155
# 3045  1595       55  200000000.0  2.201647e+09     2253    194.0           549
# 6663   524       55  245000000.0  2.069522e+09     1540    138.0           548
# 7244  2241       55  321000000.0  2.048360e+09     1606    149.0           163

# %%
correlation_matrix = df_numerized.corr(method = 'pearson')

sns.heatmap(correlation_matrix, annot = True)

plt.title('Correlation Matrix for Numeric Features')

plt.xlabel('Movie features')

plt.ylabel('Movie features')

plt.show()

# %%
df_numerized.corr()
# Out:
#                   name    rating     genre      year  released     score  \
# name          1.000000 -0.008069  0.016355  0.011453 -0.011311  0.017097
# rating       -0.008069  1.000000  0.072423  0.008779  0.016613 -0.001314
# genre         0.016355  0.072423  1.000000 -0.081261  0.029822  0.027965
# year          0.011453  0.008779 -0.081261  1.000000 -0.000695  0.097995
# released     -0.011311  0.016613  0.029822 -0.000695  1.000000  0.042788
# score         0.017097 -0.001314  0.027965  0.097995  0.042788  1.000000
# votes         0.013088  0.033225 -0.145307  0.222945  0.016097  0.409182
# director      0.009079  0.019483 -0.015258 -0.020795 -0.001478  0.009559
# writer        0.009081 -0.005921  0.006567 -0.008656 -0.002404  0.019416
# star          0.006472  0.013405 -0.005477 -0.027242  0.015777 -0.001609
# country      -0.010737  0.081244 -0.037615 -0.070938 -0.020427 -0.133348
# budget        0.023970 -0.176002 -0.356564  0.329321  0.014683  0.076254
# gross         0.005533 -0.107339 -0.235650  0.257486  0.001659  0.186258
# company       0.009211 -0.032943 -0.071067 -0.010431 -0.010474  0.001030
# runtime       0.010392  0.062145 -0.052711  0.120811  0.000868  0.399451
# year_correct -0.009383  0.013123  0.029351 -0.002874  0.992907  0.041941
#
#                  votes  director    writer      star   country    budget  \
# name          0.013088  0.009079  0.009081  0.006472 -0.010737  0.023970
# rating        0.033225  0.019483 -0.005921  0.013405  0.081244 -0.176002
# genre        -0.145307 -0.015258  0.006567 -0.005477 -0.037615 -0.356564
# year          0.222945 -0.020795 -0.008656 -0.027242 -0.070938  0.329321
# released      0.016097 -0.001478 -0.002404  0.015777 -0.020427  0.014683
# score         0.409182  0.009559  0.019416 -0.001609 -0.133348  0.076254
# votes         1.000000  0.000260  0.000892 -0.019282  0.073625  0.442429
# director      0.000260  1.000000  0.299067  0.039234  0.017490 -0.012272
# writer        0.000892  0.299067  1.000000  0.027245  0.015343 -0.039451
# star         -0.019282  0.039234  0.027245  1.000000 -0.012998 -0.019589
# country       0.073625  0.017490  0.015343 -0.012998  1.000000  0.054063
# budget        0.442429 -0.012272 -0.039451 -0.019589  0.054063  1.000000
# gross         0.630757 -0.014441 -0.023519 -0.002717  0.092129  0.740395
# company       0.133204  0.004404  0.005646  0.012442  0.095548  0.173214
# runtime       0.309212  0.017624 -0.003511  0.010174 -0.078412  0.320447
# year_correct  0.019155 -0.001809 -0.003865  0.016306 -0.022033  0.023505
#
#                  gross   company   runtime  year_correct
# name          0.005533  0.009211  0.010392     -0.009383
# rating       -0.107339 -0.032943  0.062145      0.013123
# genre        -0.235650 -0.071067 -0.052711      0.029351
# year          0.257486 -0.010431  0.120811     -0.002874
# released      0.001659 -0.010474  0.000868      0.992907
# score         0.186258  0.001030  0.399451      0.041941
# votes         0.630757  0.133204  0.309212      0.019155
# director     -0.014441  0.004404  0.017624     -0.001809
# writer       -0.023519  0.005646 -0.003511     -0.003865
# star         -0.002717  0.012442  0.010174      0.016306
# country       0.092129  0.095548 -0.078412     -0.022033
# budget        0.740395  0.173214  0.320447      0.023505
# gross         1.000000  0.154840  0.245216      0.007796
# company       0.154840  1.000000  0.034402     -0.011219
# runtime       0.245216  0.034402  1.000000      0.000476
# year_correct  0.007796 -0.011219  0.000476      1.000000

# %%
correlation_mat = df_numerized.corr()

corr_pairs = correlation_mat.unstack()

corr_pairs
# Out:
# name          name            1.000000
#               rating         -0.008069
#               genre           0.016355
#               year            0.011453
#               released       -0.011311
#               score           0.017097
#               votes           0.013088
#               director        0.009079
#               writer          0.009081
#               star            0.006472
#               country        -0.010737
#               budget          0.023970
#               gross           0.005533
#               company         0.009211
#               runtime         0.010392
#               year_correct   -0.009383
# rating        name           -0.008069
#               rating          1.000000
#               genre           0.072423
#               year            0.008779
#               released        0.016613
#               score          -0.001314
#               votes           0.033225
#               director        0.019483
#               writer         -0.005921
#               star            0.013405
#               country         0.081244
#               budget         -0.176002
#               gross          -0.107339
#               company        -0.032943
#               runtime         0.062145
#               year_correct    0.013123
# genre         name            0.016355
#               rating          0.072423
#               genre           1.000000
#               year           -0.081261
#               released        0.029822
#               score           0.027965
#               votes          -0.145307
#               director       -0.015258
#               writer          0.006567
#               star           -0.005477
#               country        -0.037615
#               budget         -0.356564
#               gross          -0.235650
#               company        -0.071067
#               runtime        -0.052711
#               year_correct    0.029351
# year          name            0.011453
#               rating          0.008779
#               genre          -0.081261
#               year            1.000000
#               released       -0.000695
#               score           0.097995
#               votes           0.222945
#               director       -0.020795
#               writer         -0.008656
#               star           -0.027242
#               country        -0.070938
#               budget          0.329321
#               gross           0.257486
#               company        -0.010431
#               runtime         0.120811
#               year_correct   -0.002874
# released      name           -0.011311
#               rating          0.016613
#               genre           0.029822
#               year           -0.000695
#               released        1.000000
#               score           0.042788
#               votes           0.016097
#               director       -0.001478
#               writer         -0.002404
#               star            0.015777
#               country        -0.020427
#               budget          0.014683
#               gross           0.001659
#               company        -0.010474
#               runtime         0.000868
#               year_correct    0.992907
# score         name            0.017097
#               rating         -0.001314
#               genre           0.027965
#               year            0.097995
#               released        0.042788
#               score           1.000000
#               votes           0.409182
#               director        0.009559
#               writer          0.019416
#               star           -0.001609
#               country        -0.133348
#               budget          0.076254
#               gross           0.186258
#               company         0.001030
#               runtime         0.399451
#               year_correct    0.041941
# votes         name            0.013088
#               rating          0.033225
#               genre          -0.145307
#               year            0.222945
#               released        0.016097
#               score           0.409182
#               votes           1.000000
#               director        0.000260
#               writer          0.000892
#               star           -0.019282
#               country         0.073625
#               budget          0.442429
#               gross           0.630757
#               company         0.133204
#               runtime         0.309212
#               year_correct    0.019155
# director      name            0.009079
#               rating          0.019483
#               genre          -0.015258
#               year           -0.020795
#               released       -0.001478
#               score           0.009559
#               votes           0.000260
#               director        1.000000
#               writer          0.299067
#               star            0.039234
#               country         0.017490
#               budget         -0.012272
#               gross          -0.014441
#               company         0.004404
#               runtime         0.017624
#               year_correct   -0.001809
# writer        name            0.009081
#               rating         -0.005921
#               genre           0.006567
#               year           -0.008656
#               released       -0.002404
#               score           0.019416
#               votes           0.000892
#               director        0.299067
#               writer          1.000000
#               star            0.027245
#               country         0.015343
#               budget         -0.039451
#               gross          -0.023519
#               company         0.005646
#               runtime        -0.003511
#               year_correct   -0.003865
# star          name            0.006472
#               rating          0.013405
#               genre          -0.005477
#               year           -0.027242
#               released        0.015777
#               score          -0.001609
#               votes          -0.019282
#               director        0.039234
#               writer          0.027245
#               star            1.000000
#               country        -0.012998
#               budget         -0.019589
#               gross          -0.002717
#               company         0.012442
#               runtime         0.010174
#               year_correct    0.016306
# country       name           -0.010737
#               rating          0.081244
#               genre          -0.037615
#               year           -0.070938
#               released       -0.020427
#               score          -0.133348
#               votes           0.073625
#               director        0.017490
#               writer          0.015343
#               star           -0.012998
#               country         1.000000
#               budget          0.054063
#               gross           0.092129
#               company         0.095548
#               runtime        -0.078412
#               year_correct   -0.022033
# budget        name            0.023970
#               rating         -0.176002
#               genre          -0.356564
#               year            0.329321
#               released        0.014683
#               score           0.076254
#               votes           0.442429
#               director       -0.012272
#               writer         -0.039451
#               star           -0.019589
#               country         0.054063
#               budget          1.000000
#               gross           0.740395
#               company         0.173214
#               runtime         0.320447
#               year_correct    0.023505
# gross         name            0.005533
#               rating         -0.107339
#               genre          -0.235650
#               year            0.257486
#               released        0.001659
#               score           0.186258
#               votes           0.630757
#               director       -0.014441
#               writer         -0.023519
#               star           -0.002717
#               country         0.092129
#               budget          0.740395
#               gross           1.000000
#               company         0.154840
#               runtime         0.245216
#               year_correct    0.007796
# company       name            0.009211
#               rating         -0.032943
#               genre          -0.071067
#               year           -0.010431
#               released       -0.010474
#               score           0.001030
#               votes           0.133204
#               director        0.004404
#               writer          0.005646
#               star            0.012442
#               country         0.095548
#               budget          0.173214
#               gross           0.154840
#               company         1.000000
#               runtime         0.034402
#               year_correct   -0.011219
# runtime       name            0.010392
#               rating          0.062145
#               genre          -0.052711
#               year            0.120811
#               released        0.000868
#               score           0.399451
#               votes           0.309212
#               director        0.017624
#               writer         -0.003511
#               star            0.010174
#               country        -0.078412
#               budget          0.320447
#               gross           0.245216
#               company         0.034402
#               runtime         1.000000
#               year_correct    0.000476
# year_correct  name           -0.009383
#               rating          0.013123
#               genre           0.029351
#               year           -0.002874
#               released        0.992907
#               score           0.041941
#               votes           0.019155
#               director       -0.001809
#               writer         -0.003865
#               star            0.016306
#               country        -0.022033
#               budget          0.023505
#               gross           0.007796
#               company        -0.011219
#               runtime         0.000476
#               year_correct    1.000000
# dtype: float64

# %%
sorted_pairs = corr_pairs.sort_values()

sorted_pairs
# Out:
# genre         budget         -0.356564
# budget        genre          -0.356564
# genre         gross          -0.235650
# gross         genre          -0.235650
# budget        rating         -0.176002
# rating        budget         -0.176002
# votes         genre          -0.145307
# genre         votes          -0.145307
# country       score          -0.133348
# score         country        -0.133348
# rating        gross          -0.107339
# gross         rating         -0.107339
# year          genre          -0.081261
# genre         year           -0.081261
# country       runtime        -0.078412
# runtime       country        -0.078412
# company       genre          -0.071067
# genre         company        -0.071067
# country       year           -0.070938
# year          country        -0.070938
# runtime       genre          -0.052711
# genre         runtime        -0.052711
# budget        writer         -0.039451
# writer        budget         -0.039451
# country       genre          -0.037615
# genre         country        -0.037615
# rating        company        -0.032943
# company       rating         -0.032943
# star          year           -0.027242
# year          star           -0.027242
# writer        gross          -0.023519
# gross         writer         -0.023519
# year_correct  country        -0.022033
# country       year_correct   -0.022033
# year          director       -0.020795
# director      year           -0.020795
# released      country        -0.020427
# country       released       -0.020427
# budget        star           -0.019589
# star          budget         -0.019589
# votes         star           -0.019282
# star          votes          -0.019282
# genre         director       -0.015258
# director      genre          -0.015258
#               gross          -0.014441
# gross         director       -0.014441
# star          country        -0.012998
# country       star           -0.012998
# budget        director       -0.012272
# director      budget         -0.012272
# name          released       -0.011311
# released      name           -0.011311
# year_correct  company        -0.011219
# company       year_correct   -0.011219
# country       name           -0.010737
# name          country        -0.010737
# released      company        -0.010474
# company       released       -0.010474
# year          company        -0.010431
# company       year           -0.010431
# year_correct  name           -0.009383
# name          year_correct   -0.009383
# year          writer         -0.008656
# writer        year           -0.008656
# name          rating         -0.008069
# rating        name           -0.008069
# writer        rating         -0.005921
# rating        writer         -0.005921
# star          genre          -0.005477
# genre         star           -0.005477
# year_correct  writer         -0.003865
# writer        year_correct   -0.003865
#               runtime        -0.003511
# runtime       writer         -0.003511
# year          year_correct   -0.002874
# year_correct  year           -0.002874
# gross         star           -0.002717
# star          gross          -0.002717
# writer        released       -0.002404
# released      writer         -0.002404
# director      year_correct   -0.001809
# year_correct  director       -0.001809
# star          score          -0.001609
# score         star           -0.001609
# director      released       -0.001478
# released      director       -0.001478
# score         rating         -0.001314
# rating        score          -0.001314
# released      year           -0.000695
# year          released       -0.000695
# director      votes           0.000260
# votes         director        0.000260
# runtime       year_correct    0.000476
# year_correct  runtime         0.000476
# runtime       released        0.000868
# released      runtime         0.000868
# votes         writer          0.000892
# writer        votes           0.000892
# score         company         0.001030
# company       score           0.001030
# released      gross           0.001659
# gross         released        0.001659
# company       director        0.004404
# director      company         0.004404
# name          gross           0.005533
# gross         name            0.005533
# writer        company         0.005646
# company       writer          0.005646
# star          name            0.006472
# name          star            0.006472
# writer        genre           0.006567
# genre         writer          0.006567
# gross         year_correct    0.007796
# year_correct  gross           0.007796
# rating        year            0.008779
# year          rating          0.008779
# name          director        0.009079
# director      name            0.009079
# name          writer          0.009081
# writer        name            0.009081
# company       name            0.009211
# name          company         0.009211
# score         director        0.009559
# director      score           0.009559
# runtime       star            0.010174
# star          runtime         0.010174
# name          runtime         0.010392
# runtime       name            0.010392
# name          year            0.011453
# year          name            0.011453
# star          company         0.012442
# company       star            0.012442
# name          votes           0.013088
# votes         name            0.013088
# year_correct  rating          0.013123
# rating        year_correct    0.013123
#               star            0.013405
# star          rating          0.013405
# budget        released        0.014683
# released      budget          0.014683
# writer        country         0.015343
# country       writer          0.015343
# released      star            0.015777
# star          released        0.015777
# votes         released        0.016097
# released      votes           0.016097
# star          year_correct    0.016306
# year_correct  star            0.016306
# genre         name            0.016355
# name          genre           0.016355
# released      rating          0.016613
# rating        released        0.016613
# score         name            0.017097
# name          score           0.017097
# country       director        0.017490
# director      country         0.017490
#               runtime         0.017624
# runtime       director        0.017624
# year_correct  votes           0.019155
# votes         year_correct    0.019155
# score         writer          0.019416
# writer        score           0.019416
# rating        director        0.019483
# director      rating          0.019483
# budget        year_correct    0.023505
# year_correct  budget          0.023505
# budget        name            0.023970
# name          budget          0.023970
# star          writer          0.027245
# writer        star            0.027245
# score         genre           0.027965
# genre         score           0.027965
#               year_correct    0.029351
# year_correct  genre           0.029351
# genre         released        0.029822
# released      genre           0.029822
# rating        votes           0.033225
# votes         rating          0.033225
# runtime       company         0.034402
# company       runtime         0.034402
# director      star            0.039234
# star          director        0.039234
# year_correct  score           0.041941
# score         year_correct    0.041941
#               released        0.042788
# released      score           0.042788
# budget        country         0.054063
# country       budget          0.054063
# runtime       rating          0.062145
# rating        runtime         0.062145
#               genre           0.072423
# genre         rating          0.072423
# country       votes           0.073625
# votes         country         0.073625
# score         budget          0.076254
# budget        score           0.076254
# country       rating          0.081244
# rating        country         0.081244
# country       gross           0.092129
# gross         country         0.092129
# company       country         0.095548
# country       company         0.095548
# year          score           0.097995
# score         year            0.097995
# year          runtime         0.120811
# runtime       year            0.120811
# votes         company         0.133204
# company       votes           0.133204
#               gross           0.154840
# gross         company         0.154840
# budget        company         0.173214
# company       budget          0.173214
# gross         score           0.186258
# score         gross           0.186258
# votes         year            0.222945
# year          votes           0.222945
# runtime       gross           0.245216
# gross         runtime         0.245216
#               year            0.257486
# year          gross           0.257486
# director      writer          0.299067
# writer        director        0.299067
# votes         runtime         0.309212
# runtime       votes           0.309212
#               budget          0.320447
# budget        runtime         0.320447
#               year            0.329321
# year          budget          0.329321
# score         runtime         0.399451
# runtime       score           0.399451
# votes         score           0.409182
# score         votes           0.409182
# budget        votes           0.442429
# votes         budget          0.442429
# gross         votes           0.630757
# votes         gross           0.630757
# gross         budget          0.740395
# budget        gross           0.740395
# year_correct  released        0.992907
# released      year_correct    0.992907
# name          name            1.000000
# company       company         1.000000
# gross         gross           1.000000
# budget        budget          1.000000
# country       country         1.000000
# star          star            1.000000
# writer        writer          1.000000
# director      director        1.000000
# votes         votes           1.000000
# score         score           1.000000
# released      released        1.000000
# year          year            1.000000
# genre         genre           1.000000
# rating        rating          1.000000
# runtime       runtime         1.000000
# year_correct  year_correct    1.000000
# dtype: float64

# %%
high_corr = sorted_pairs[(sorted_pairs) > 0.5]

high_corr
# Out:
# gross         votes           0.630757
# votes         gross           0.630757
# gross         budget          0.740395
# budget        gross           0.740395
# year_correct  released        0.992907
# released      year_correct    0.992907
# name          name            1.000000
# company       company         1.000000
# gross         gross           1.000000
# budget        budget          1.000000
# country       country         1.000000
# star          star            1.000000
# writer        writer          1.000000
# director      director        1.000000
# votes         votes           1.000000
# score         score           1.000000
# released      released        1.000000
# year          year            1.000000
# genre         genre           1.000000
# rating        rating          1.000000
# runtime       runtime         1.000000
# year_correct  year_correct    1.000000
# dtype: float64

# %%
# Votes and budget have the highest correlation to gross earnings

# Company has low correlation
